# %% [markdown]
# ### THis is MBTI personality test, using dataset from Kaggle

# %%
import kagglehub
import os
import pandas as pd
import numpy as np

path = kagglehub.dataset_download("anshulmehtakaggl/60k-responses-of-16-personalities-test-mbt")

df = pd.read_csv(os.path.join(path, os.listdir(path)[0]), encoding='latin1')
df.sample(13)
# Out:
#        Response Id  You regularly make new friends.  \
# 6497          6497                                0
# 7826          7826                                0
# 20960        20960                                0
# 24307        24307                               -1
# 35257        35257                                0
# 36125        36125                                0
# 18237        18237                                0
# 16897        16897                                0
# 40073        40073                                1
# 55568        55568                                0
# 48147        48147                                0
# 46286        46286                                0
# 35438        35438                                0
#
#        You spend a lot of your free time exploring various random topics that pique your interest  \
# 6497                                                   0
# 7826                                                   0
# ...

# %%
df.shape
# Out:
# (59999, 62)

# %% [markdown]
# ##### separate X and y (features and labels)

# %%
X = df[df.columns[1:-1]]
y = df[df.columns[-1]]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y = encoder.fit_transform(y)

y_labels = encoder.inverse_transform(y)
y_labels
# Out:
# array(['ENFP', 'ISFP', 'INFJ', ..., 'ISTP', 'ISTJ', 'INFJ'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_test.shape, X_train.shape
# Out:
# ((12000, 60), (47999, 60))

# %% [markdown]
# ### Pipeline for seamless flow for end-to-end product

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
classifier = RandomForestClassifier(
  n_estimators=155, 
  random_state=42, 
  max_depth=50, 
  min_samples_split=10, 
  max_features='sqrt'
)

pipeline = make_pipeline(scaler, classifier)

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=50, min_samples_split=10,
#                                         n_estimators=155, random_state=42))])

# %%
y_pred = pipeline.predict(X_test)

# %% [markdown]
# #### accuracy_score vs f1_score for my model

# %%
from sklearn.metrics import accuracy_score, f1_score
print("accuracy score: ", accuracy_score(y_test, y_pred))
print("f1 score: ", f1_score(y_test, y_pred, average='macro'))
# Out:
# accuracy score:  0.9746666666666667
# f1 score:  0.9746459221110808

# %% [markdown]
# ##### pack for the production

# %%
# import joblib
# joblib.dump(pipeline, "pkl/model.pkl", compress=6)
# joblib.dump(encoder, "pkl/encoder.pkl")
# joblib.dump(list(df.columns[1:-1]), "pkl/columns.pkl")
